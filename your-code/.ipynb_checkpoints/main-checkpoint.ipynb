# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
import calendar
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
plt.rcParams['figure.figsize'] = (12, 4)

# %matplotlib inline

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit.columns=[e.lower().replace(' ', '_') for e in fitbit.columns]

# %%
fitbit.head()
# Out:
#          date  calorie_burned  steps  distance  floors  minutes_sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    minutes_lightly_active  minutes_fairly_active  minutes_very_active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    activity_calories  ...  distance_miles      days  days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
data = fitbit.groupby('months')['steps'].mean().reindex([calendar.month_name[i] for i in range(1, 13)])

# %%
sns.barplot(x=data.index,
            y=data.values,
            width = 0.5)

plt.xticks(rotation=35)
plt.xlabel = "meses"

plt.savefig('months_steps.png');

# %%
data2 = fitbit.groupby('work_or_weekend')['steps'].mean()

# %%
plt.pie(data2, labels = ['work', 'weekend'], autopct='%1.1f%%', startangle=140)
plt.savefig('work_weekend_steps.png');

# %% [markdown]
# ## Write a loop to plot 3 scatter plots of the following features:
#
# - Minutes lightly active vs steps
# - Minutes very active vs steps
# - Minutes sedentary vs steps

# %%
parejas = [('minutes_lightly_active', 'steps'),
           ('minutes_very_active', 'steps'),
           ('minutes_sedentary', 'steps')]

# Create a loop to generate scatter plots for each pair of features
for i, (x_feature, y_feature) in enumerate(parejas, start=1):
    plt.figure(figsize=(4, 4))
    
    x_data = fitbit[x_feature]
    y_data = fitbit[y_feature]
    
    # Create the scatter plot
    plt.scatter(x_data, y_data, alpha=0.5)
    
    plt.savefig(f'scatter{i}.png');

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv('../data/titanic.csv')

titanic.columns=[e.lower().replace(' ', '_') for e in titanic.columns]

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 name  gender   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# passengerid      int64
# survived       float64
# pclass           int64
# name            object
# gender          object
# age            float64
# sibsp            int64
# parch            int64
# ticket          object
# fare           float64
# cabin           object
# embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
titanic.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['name', 'gender', 'ticket', 'cabin', 'embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
plt.rcParams['figure.figsize'] = (12, 6)
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(data = titanic.age, color = 'y')

plt.xticks(rotation=35)
plt.ylabel('número de personas')

plt.savefig('age_histogram.png');

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
bins = [10, 20 , 50]
for i in bins:
    sns.histplot(data = titanic.age, bins = i, kde = True)
    
    plt.xticks(rotation=35)
    plt.ylabel('número de personas')
    
    plt.savefig('age_bins.png');

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# Vemos que cuanto menor es el número de columnas establecido más picuda es la forma de la linea, lo que indica una sobrerepresentación de ciertos grupos.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.histplot(data = titanic.age, color = 'y')

plt.xticks(rotation=35)
plt.ylabel('número de personas');

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic['gender'].value_counts().plot(kind='bar');

# %%
sns.countplot(data=titanic, x='gender')
plt.savefig('titanic_age.png');

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(data=titanic, x='pclass')
plt.savefig('titanic_pclass.png');

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic.age.describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: age, dtype: float64

# %%
mean_age = titanic['age'].mean()
mode_age = titanic['age'].mode().values[0]
median_age = titanic['age'].median()

sns.histplot(data=titanic, x='age', color='w', bins=40)

plt.ylabel('recuento personas')

plt.axvline(mean_age, color='r', linestyle='dashed', linewidth=4)
plt.axvline(mode_age, color='g', linestyle='dashed', linewidth=4)
plt.axvline(median_age, color='y', linestyle='dashed', linewidth=4)

plt.savefig('titanic_age_desc.png');

# %% [markdown]
# Rojo: media
# Amarillo: mediana
# Verde: moda
# Vemos que la media es el valor más alto, esto debido a su sensibilidad a los valores extremos, cómo pueden ser los pasajeros de 70-80 años. También vemos que la moda se encuentra alrededor de los 24-25 años y que la mediana esta sobre los 29, lo que nos indica que hay el mismo número de pasajeros menores de 29 que mayores.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.scatter(titanic.fare, titanic.age)
plt.xlim(0,500)
plt.ylim(0);

# %%
sns.scatterplot(data=titanic, x='fare', y='age', color='r')
plt.xlim(0,500)
plt.ylim(0)
plt.savefig('titanic_fare_age.png');

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
numer = titanic.select_dtypes(include=['int64', 'float64'])

# %%
numer = numer.corr()

# %%
sns.scatterplot(data=numer);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
age_mean_by_class = titanic.groupby('pclass')['age'].mean().reset_index()

sns.barplot(data=age_mean_by_class, x='pclass', y='age', palette='Blues');

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col="gender", margin_titles=True, height=4)

g.map(plt.hist, "age", bins=20, color="skyblue")

# Add labels and titles
g.set_axis_labels("age", "count")
g.set_titles(col_template="gender = {col_name}")
plt.savefig('titanic_age_gen.png');
# Out:
# /Users/joaquin/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
