# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import numpy as np
import pylab as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Challenge
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv("../data/Fitbit2.csv")

# %%
fitbit.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  MinutesOfSleep  MinutesOfBeingAwake  NumberOfAwakings  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays?
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# AVERAGE STEPS BY MONTH_ENCODED
# your code here
x = fitbit.groupby('Months_encoded').agg({"Steps":"mean"}).reset_index()

# Graficar el promedio por mes con Seaborn
plt.figure(figsize=(12, 4))
sns.barplot(x='Months_encoded', y='Steps', data=x, palette='viridis')
plt.xlabel('Mes')
plt.ylabel('Pasos promedio')
plt.title('Promedio de pasos por Mes')
plt.xticks(rotation=45)
plt.show();

# %%
# AVERAGE STEPS BY WORK_OR_WEEKEND
# your code here
x = fitbit.groupby('Work_or_Weekend').agg({"Steps":"mean"}).reset_index()
plt.figure(figsize=(12, 4))
sns.barplot(x='Work_or_Weekend', y='Steps', data=x, palette='viridis')
plt.xlabel('Work_or_Weekend')
plt.ylabel('Pasos promedio')
plt.title('Promedio de pasos por tipo de día')
plt.xticks(rotation=45)
plt.show();

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
lista = ["Minutes Lightly Active","Minutes Very Active","Minutes Sedentary"]
for col in lista:
    sns.scatterplot(data=fitbit, x='Steps', y= col)
    plt.title(f'Steps vs {col}')
    plt.xlabel('Steps')
    plt.ylabel(col)
    plt.show();

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("../data/titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')

plt.figure(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
bins = [10,20,50]
for b in bins:   
    sns.histplot(x=titanic.Age,
                 bins=b
                );

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
El tamaño de los bins en un histograma puede influir
significativamente en la apariencia y la interpretación de los datos. 
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(x=titanic.Age,
                 bins=50
                );

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.hist(titanic.Gender,bins=2,edgecolor='black', color='skyblue')  # Crear el histograma con 30 bins y bordes negros

# Etiquetas y título
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Genders')

plt.show();

# %%
# Method 2 - seaborn
# your code here
labels = ["Male","Female"]
plt.pie(titanic.Gender.value_counts(),labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Asegura que el gráfico de pastel se vea como un círculo

plt.show();

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
plt.hist(titanic.Pclass,bins=3, color='skyblue') 

# Etiquetas y título
plt.xlabel('Class')
plt.ylabel('Count')
plt.title('Classes')
plt.xticks(np.arange(1, 3, step=1)) 
plt.show();

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(data=titanic.Age, color='yellow');

# %%
"""
El boxplot sirve como un resumen de los valores estadísticos de la columna Age.
"""
# Out:
# '\nEl boxplot sirve como un resumen de los valores estadísticos de la columna Age.\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
La mitad de los tripulantes se encuentra en el rango de edad entre 22 y 37 años. 
La media de edad es de 30 años
"""
# Out:
# '\nLa mitad de los tripulantes se encuentra en el rango de edad entre 22 y 37 años. \nLa media de edad es de 30 años\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.violinplot(data=titanic.Age);

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Muestra la distribución completa de los datos incluyendo su forma, simetría, modas y otros detalles.
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(x=titanic['Fare'], y=titanic['Age'])
plt.xlabel('Fare')
plt.ylabel('Age')
plt.xlim(0, 300) 
plt.ylim(0, 100)
plt.show();

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x=titanic['Fare'], y=titanic['Age'])
plt.xlabel('Fare')
plt.ylabel('Age')
plt.xlim(0, 300) 
plt.ylim(0, 100)
plt.show();

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
corr = titanic.corr()
sns.set(style='white')       # estilo blanco

mascara = np.triu(np.ones_like(corr, dtype=bool))   # mascara

cmap = sns.diverging_palette(0, 10, as_cmap=True)   # paleta de colores



sns.heatmap(corr,             # datos
            mask=mascara,     # mascara
            cmap=cmap,        # mapa de color
            
            vmax=1,           # maximo vertical
            vmin=-1,          # minimo vertical
            center=0,         # centro
            
            square=True,      # cuadrado el dato pintado
            linewidth=0.5,    # ancho de la linea
            
            cbar_kws={'shrink': 0.5},  # barra de color
            annot=True                 # anotacion, el numero escrito
            
           );
# Out:
# C:\Users\daarr\AppData\Local\Temp\ipykernel_53376\69363331.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = titanic.corr()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""

La clase tiene una alta correlación inversa tanto con la edad como con el precio pagado.

"""
# Out:
# '\n\nLa clase tiene una alta correlación inversa tanto con la edad como con el precio pagado.\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x='Pclass', y='Age', data=titanic)
plt.title('Summary Statistics of Age by Pclass')
plt.show();

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
g = sns.FacetGrid(titanic, col='Gender', height=4, aspect=1.5)
g.map(sns.histplot, 'Age')
plt.xlabel('Age')
plt.ylabel('Count')

plt.suptitle('Distribution of Age based on Gender', y=1.05)
plt.show();
